# %%
import pandas as pd 
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, TreebankWordTokenizer
import string

df = pd.io.parsers.read_csv('https://raw.githubusercontent.com/fuzhenxin/textstyletransferdata/master/sentiment/neg.txt',header=None, sep="\n", names = ["Sentences"])
df.head()
# Out:
#                                            Sentences
# 0         I bought this when I bought the pop maker.
# 1  As for "pop embellishing" well, that wasn't to...
# 2  I'd save the money and spend it instead on ext...
# 3       didn't really care many of the cakes at all.
# 4  not up to normal standing for wilton yearbooks...

# %%
df["Words"] = df["Sentences"].apply(word_tokenize)
df.head()
# Out:
#                                            Sentences  \
# 0         I bought this when I bought the pop maker.
# 1  As for "pop embellishing" well, that wasn't to...
# 2  I'd save the money and spend it instead on ext...
# 3       didn't really care many of the cakes at all.
# 4  not up to normal standing for wilton yearbooks...
#
#                                                Words
# 0  [I, bought, this, when, I, bought, the, pop, m...
# 1  [As, for, ``, pop, embellishing, '', well, ,, ...
# 2  [I, 'd, save, the, money, and, spend, it, inst...
# 3  [did, n't, really, care, many, of, the, cakes,...
# 4  [not, up, to, normal, standing, for, wilton, y...

# %%
df_token = pd.DataFrame(df["Words"])
df_token.head()
# Out:
#                                                Words
# 0  [I, bought, this, when, I, bought, the, pop, m...
# 1  [As, for, ``, pop, embellishing, '', well, ,, ...
# 2  [I, 'd, save, the, money, and, spend, it, inst...
# 3  [did, n't, really, care, many, of, the, cakes,...
# 4  [not, up, to, normal, standing, for, wilton, y...
